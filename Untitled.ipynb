# %% [markdown]
# # A BASIC MACHINE LEARNING PROJECT ON THE FAMOUS IRIS DATASET

# %% [markdown]
# It takes the IRIS DATASET as input and does some exploration and finds similarity between the features and tires to predict to which species of Iris flower will it belong to using different and various machine learning algorithms.

# %% [markdown]
# ## IMPORTING THE REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # LOADING THE IRIS DATASET

# %%
iris = pd.read_csv("iris.data",names=['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class'])

# %%
iris.loc[30:80]
# Out:
#     sepal-length  sepal-width  petal-length  petal-width            class
# 30           4.8          3.1           1.6          0.2      Iris-setosa
# 31           5.4          3.4           1.5          0.4      Iris-setosa
# 32           5.2          4.1           1.5          0.1      Iris-setosa
# 33           5.5          4.2           1.4          0.2      Iris-setosa
# 34           4.9          3.1           1.5          0.1      Iris-setosa
# 35           5.0          3.2           1.2          0.2      Iris-setosa
# 36           5.5          3.5           1.3          0.2      Iris-setosa
# 37           4.9          3.1           1.5          0.1      Iris-setosa
# 38           4.4          3.0           1.3          0.2      Iris-setosa
# 39           5.1          3.4           1.5          0.2      Iris-setosa
# 40           5.0          3.5           1.3          0.3      Iris-setosa
# 41           4.5          2.3           1.3          0.3      Iris-setosa
# ...

# %% [markdown]
# ## Lets have a statistical overview as to what is in the dataset using the describe() function in Pandas

# %%
iris.describe()
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Lets have a class distribution denoting the no of instances belonging of each class of species

# %%
iris.groupby('class').count()
# Out:
#                  sepal-length  sepal-width  petal-length  petal-width
# class
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %% [markdown]
#  This shows there are 50 instances of each class of species of the IRIS flower

# %% [markdown]
# # VISUALIZING THE DATASET

# %%
iris.plot(kind='box', subplots=True, figsize=(20,8))
plt.show()

# %%
iris.plot(kind='hist' ,subplots=True,figsize=(10,15))
plt.show()

# %% [markdown]
#        This gives an idea of frequency distribution of each feature of the species

# %%
scatter_matrix(iris,figsize=(20,9),s=40,marker='o')
plt.show()

# %% [markdown]
#                  This scatter matrix shows the relationship of different features with respect to each other.

# %% [markdown]
# # Lets do the validation of the dataset using different models

# %% [markdown]
# ## For thet lets split the datset into two i.e train and test dataset

# %% [markdown]
# ### SInce the class labels are in the form of strings so its better to convert them into distinct objects using numpy library

# %%
from sklearn.model_selection import train_test_split
array = iris.values
X = array[:,0:4]
y = array[:,4]
X_train, X_test, Y_train, Y_test = train_test_split(X, y,random_state=1)

# %%
X_train
# Out:
# array([[6.5, 2.8, 4.6, 1.5],
#        [6.7, 2.5, 5.8, 1.8],
#        [6.8, 3.0, 5.5, 2.1],
#        [5.1, 3.5, 1.4, 0.3],
#        [6.0, 2.2, 5.0, 1.5],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.6, 2.9, 4.6, 1.3],
#        [7.7, 2.6, 6.9, 2.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.0, 3.6, 1.4, 0.2],
#        [4.8, 3.0, 1.4, 0.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [7.7, 3.8, 6.7, 2.2],
#        [6.9, 3.1, 5.4, 2.1],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.0, 3.4, 4.5, 1.6],
#        [7.7, 2.8, 6.7, 2.0],
#        [5.7, 3.0, 4.2, 1.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [5.7, 2.5, 5.0, 2.0],
#        [6.3, 2.7, 4.9, 1.8],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.7, 3.2, 1.3, 0.2],
#        [6.5, 3.0, 5.8, 2.2],
#        [4.6, 3.4, 1.4, 0.3],
#        [6.1, 3.0, 4.9, 1.8],
#        [6.5, 3.2, 5.1, 2.0],
#        [6.7, 3.1, 4.4, 1.4],
# ...

# %%
Y_train
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
# ...

# %% [markdown]
# ## LOADING THE LIBRARIES FOR DIFFERENT ML MODELS

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('SVM', SVC(gamma='auto')))
results = []
names = []
resultmean=[]
for name, model in models:
        kfold = StratifiedKFold(n_splits=10, random_state=0, shuffle=True)
        cv_results = cross_val_score(model, X_train, Y_train, cv=kfold)
        results.append(cv_results)
        resultmean.append(cv_results.mean())
        names.append(name)
        print('{}: {}'.format(name,cv_results.mean()))
# Out:
# LR: 0.9378787878787878
# KNN: 0.9469696969696969
# CART: 0.9371212121212121
# SVM: 0.9825757575757577

# %% [markdown]
# This evaluates each models 'accuracy' at the the go and gives the score after cross validating the train and test data.Since SVM(Support vector machine) gives the highest accuracy it seems the perfect fit for our ML model.

# %% [markdown]
# ## Lets compare the prefermance of algorithms in the form of box-plots

# %%
plt.boxplot(results, labels=names)
plt.title('Algorithm Comparison')
plt.show()

# %% [markdown]
# We can see that the box and whisker plots are squashed at the top of the range, with SVM pushing upto 100% accuracy

# %%
plt.plot(names,resultmean,c='m')

# %% [markdown]
# This graph proves our point of having the highest accuracy of SVM model having the highest accuracy

# %% [markdown]
# # Making Predictions using the SVM model

# %% [markdown]
# ## Since its proved using the above visualizations that SVM models have the highest accuracy so its better to start fitting and making predictions on them

# %%
model = SVC(gamma='auto')
model.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ## Lets try finding the accuracy of our model

# %%
tset_predict= model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(Y_test, tset_predict))
# Out:
# 0.9736842105263158

# %% [markdown]
# ## Thus our model has an accuracy of 97% over the test data

# %% [markdown]
# ## Lets try predicting a a given class using our own dimensions

# %% [markdown]
# ### Lets say we want to know which class does a flower sample belong with a dimensions of {5.6,3.2,4.8,1.7}

# %%
model.predict([[5.6,3.2,4.8,1.7]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %% [markdown]
# ### As we can see the SVM model predicted the flower with our dimensions to be of the class 'Virginica'
